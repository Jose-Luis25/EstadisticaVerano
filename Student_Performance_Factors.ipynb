# %% [markdown]
# <a href="https://colab.research.google.com/github/Jose-Luis25/EstadisticaVerano/blob/main/Student_Performance_Factors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importacion de Datos

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Jose-Luis25/EstadisticaVerano/refs/heads/main/StudentPerformanceFactors.csv")
df = df.dropna()
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
# @title Horas Estudiadas

from matplotlib import pyplot as plt
df['Hours_Studied'].plot(kind='hist', bins=20, title='Hours_Studied')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Asistencia

from matplotlib import pyplot as plt
df['Attendance'].plot(kind='hist', bins=20, title='Attendance')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Atencion de los padres

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Parental_Involvement)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                              df        sum_sq      mean_sq          F  \
# C(Parental_Involvement)     2.0   2405.587354  1202.793677  80.462228
# Residual                 6375.0  95297.009071    14.948550        NaN
#
#                                PR(>F)
# C(Parental_Involvement)  3.086485e-35
# Residual                          NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Parental_Involvement'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Examen_Score")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#   High    Low  -1.7334   0.0 -2.0626 -1.4042   True
#   High Medium   -0.999   0.0 -1.2636 -0.7344   True
#    Low Medium   0.7344   0.0  0.4363  1.0326   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df['Parental_Involvement'] = df['Parental_Involvement'].map({"Low":0, "Medium":1, "High":2})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement Access_to_Resources  \
# 0                23          84                     0                High
# 1                19          64                     0              Medium
# 2                24          98                     1              Medium
# 3                29          89                     0              Medium
# 4                19          92                     1              Medium
# ...             ...         ...                   ...                 ...
# 6602             25          69                     2              Medium
# 6603             23          76                     2              Medium
# 6604             20          90                     1                 Low
# 6605             10          86                     2                High
# 6606             15          67                     1                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Acceso a Recursos

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Access_to_Resources)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                             df        sum_sq      mean_sq         F  \
# C(Access_to_Resources)     2.0   2752.911147  1376.455574  92.41636
# Residual                6375.0  94949.685278    14.894068       NaN
#
#                               PR(>F)
# C(Access_to_Resources)  2.722170e-40
# Residual                         NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Access_to_Resources'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Examen_Score")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#   High    Low  -1.8795   0.0 -2.2071 -1.5518   True
#   High Medium  -0.9468   0.0 -1.2088 -0.6848   True
#    Low Medium   0.9327   0.0   0.633  1.2323   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df['Access_to_Resources'] = df['Access_to_Resources'].map({"Low":0, "Medium":1, "High":2})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Actividades Extracurriculares

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Extracurricular_Activities)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                    df        sum_sq     mean_sq          F  \
# C(Extracurricular_Activities)     1.0    388.552812  388.552812  25.457916
# Residual                       6376.0  97314.043614   15.262554        NaN
#
#                                      PR(>F)
# C(Extracurricular_Activities)  4.646554e-07
# Residual                                NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Extracurricular_Activities'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Extracurricular_Activities")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     No    Yes   0.5032   0.0 0.3077 0.6987   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df['Extracurricular_Activities'] = df['Extracurricular_Activities'].map({"No":0, "Yes":1})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# Horas de Suenio

# %%
from matplotlib import pyplot as plt
df['Sleep_Hours'].plot(kind='hist', bins=20, title='Sleep_Hours')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Calificaciones precvias

# %%
from matplotlib import pyplot as plt
df['Previous_Scores'].plot(kind='hist', bins=20, title='Previous_Scores')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Nivel de Motivacion

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Motivation_Level)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                          df        sum_sq     mean_sq          F        PR(>F)
# C(Motivation_Level)     2.0    776.488813  388.244407  25.535515  9.000204e-12
# Residual             6375.0  96926.107612   15.204095        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Motivation_Level'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Motivation_Level")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low  -0.9794    0.0 -1.3115 -0.6474   True
#   High Medium   -0.405 0.0048 -0.7071  -0.103   True
#    Low Medium   0.5744    0.0  0.3086  0.8402   True
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df['Motivation_Level'] = df['Motivation_Level'].map({"Low":0, "Medium":1, "High":2})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Acceso a Internet

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Internet_Access)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df        sum_sq     mean_sq          F    PR(>F)
# C(Internet_Access)     1.0    255.358422  255.358422  16.708173  0.000044
# Residual            6376.0  97447.238003   15.283444        NaN       NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Internet_Access'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Internet_Access")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     No    Yes   0.7549   0.0 0.3929 1.1169   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df['Internet_Access'] = df['Internet_Access'].map({"No":0, "Yes":1})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Sesiones de Turoria

# %%
from matplotlib import pyplot as plt
df['Tutoring_Sessions'].plot(kind='hist', bins=20, title='Tutoring_Sessions')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Ingresos Familiares

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Family_Income)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                       df        sum_sq     mean_sq          F        PR(>F)
# C(Family_Income)     2.0    874.339934  437.169967  28.782492  3.597672e-13
# Residual          6375.0  96828.256491   15.188746        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Family_Income'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Family_Income")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low  -0.9882    0.0 -1.3048 -0.6717   True
#   High Medium  -0.4705 0.0015 -0.7873 -0.1536   True
#    Low Medium   0.5178    0.0  0.2631  0.7725   True
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df['Family_Income'] = df['Family_Income'].map({"Low":0, "Medium":1, "High":2})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Calidad del Profesor

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Teacher_Quality)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df        sum_sq     mean_sq         F        PR(>F)
# C(Teacher_Quality)     2.0    566.739816  283.369908  18.59749  8.844704e-09
# Residual            6375.0  97135.856609   15.236997       NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Teacher_Quality'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Teacher_Quality")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
plt.axvline(x=67.03, color='red', linestyle='--')
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low   -0.906    0.0 -1.3224 -0.4896   True
#   High Medium  -0.5632    0.0 -0.8198 -0.3066   True
#    Low Medium   0.3428 0.0971 -0.0462  0.7318  False
# ----------------------------------------------------

# %%
df['Teacher_Quality'] = df['Teacher_Quality'].map({"Low":1, "Medium":1, "High":2})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Tipo de Escuela

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(School_Type)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                     df        sum_sq    mean_sq         F    PR(>F)
# C(School_Type)     1.0     11.540237  11.540237  0.753196  0.385499
# Residual        6376.0  97691.056188  15.321684       NaN       NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['School_Type'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="School_Type")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1 group2 meandiff p-adj   lower  upper  reject
# ----------------------------------------------------
# Private Public  -0.0924 0.3855 -0.3011 0.1163  False
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df = df.drop(columns=['School_Type'])
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Influencia de los companieros

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Peer_Influence)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                        df        sum_sq     mean_sq          F        PR(>F)
# C(Peer_Influence)     2.0    976.526155  488.263077  32.180333  1.242613e-14
# Residual           6375.0  96726.070271   15.172717        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Peer_Influence'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Peer_Influence")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1   group2  meandiff p-adj  lower  upper  reject
# ------------------------------------------------------
# Negative  Neutral   0.6329    0.0 0.3229 0.9429   True
# Negative Positive   1.0538    0.0  0.745 1.3626   True
#  Neutral Positive   0.4209 0.0004 0.1638 0.6779   True
# ------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df['Peer_Influence'] = df['Peer_Influence'].map({"Negative":-1, "Neutral":0, "Positive":1})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Actividad Fisisica

# %%
from matplotlib import pyplot as plt
df['Physical_Activity'].plot(kind='hist', bins=20, title='Physical_Activity')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Dificultad de Aprendizaje

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Learning_Disabilities)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                               df        sum_sq     mean_sq          F  \
# C(Learning_Disabilities)     1.0    687.937066  687.937066  45.212618
# Residual                  6376.0  97014.659360   15.215599        NaN
#
#                                 PR(>F)
# C(Learning_Disabilities)  1.921126e-11
# Residual                           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Learning_Disabilities'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Learning_Disabilities")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#     No    Yes  -1.0725   0.0 -1.3852 -0.7598   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df['Learning_Disabilities'] = df['Learning_Disabilities'].map({"No":0, "Yes":1})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Nivel de educacion de los padres

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Parental_Education_Level)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                  df        sum_sq     mean_sq          F  \
# C(Parental_Education_Level)     2.0   1089.555877  544.777939  35.947108
# Residual                     6375.0  96613.040548   15.154987        NaN
#
#                                    PR(>F)
# C(Parental_Education_Level)  2.990498e-16
# Residual                              NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Parental_Education_Level'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Parental_Education_Level")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#    group1      group2    meandiff p-adj   lower   upper  reject
# ---------------------------------------------------------------
#     College  High School  -0.4635 0.0001 -0.7268 -0.2002   True
#     College Postgraduate   0.6142    0.0  0.2856  0.9429   True
# High School Postgraduate   1.0778    0.0  0.7754  1.3801   True
# ---------------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df['Parental_Education_Level'] = df['Parental_Education_Level'].map({"High School":0, "College":1, "Postgraduate":2})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Disctancia desde Casas

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Distance_from_Home)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                            df        sum_sq     mean_sq          F  \
# C(Distance_from_Home)     2.0    758.421410  379.210705  24.936704
# Residual               6375.0  96944.175015   15.206929        NaN
#
#                              PR(>F)
# C(Distance_from_Home)  1.630308e-11
# Residual                        NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Exam_Score'], groups=df['Distance_from_Home'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Distance_from_Home")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1   group2  meandiff p-adj lower  upper  reject
# -----------------------------------------------------
#      Far Moderate   0.4882 0.017 0.0705 0.9059   True
#      Far     Near   1.0154   0.0 0.6237  1.407   True
# Moderate     Near   0.5272   0.0 0.2722 0.7822   True
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df['Distance_from_Home'] = df['Distance_from_Home'].map({"Near":0, "Moderate":1, "Far":2})
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Genero

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Exam_Score ~ C(Gender)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                df        sum_sq    mean_sq         F    PR(>F)
# C(Gender)     1.0      2.377044   2.377044  0.155128  0.693696
# Residual   6376.0  97700.219381  15.323121       NaN       NaN

# %%
df = df.drop(columns=['Gender'])
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Puntuacion del Examen

# %%
from matplotlib import pyplot as plt
df['Exam_Score'].plot(kind='hist', bins=20, title='Physical_Activity')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Mi variable dependiente  (y) es Exam_Score

#Hours_Studied: No hay datos atipicos, es continua

#Attendance: No hay datos atipicos, es continua

#Parental_Involvement: Si hubo diferencia significativa entre
#                      grupos. Low = 0, Medium = 1, High = 2

#Access_to_Resources: Si hay diferecnia sognificativa entre
#                     grupos. Low = 0, Medium = 1, High = 2

#Extracurricular_Activities: Si hay diferecnia sognificativa entre
#                     grupos. No = 0, Yes = 1

#Sleep_Hours: Variable Numerica discreta.No hay datos atipicos, es continua

#Previous_Scores: Variable Numerica, no precenta dtos atipicos

#Motivation_Level: Si hay diferecnia sognificativa entre
#                     grupos. Low = 0, Medium = 1, High = 2

#Internet_Access: Si hay diferecnia sognificativa entre
#                     grupos. No = 0, Yes = 1

#Tutoring_Sessions: Variable Numerica Discretas, no precenta dtos atipicos

#Family_Income: Si hay diferecnia sognificativa entre
#                     grupos. Low = 0, Medium = 1, High = 2

#Teacher_Quality: Hubo diferencia significativa entre
#                     grupos. Low = 1, Medium = 1, High = 2

#School_Type: NO hubo diferencia significativa entre grupos
#              entonces se elimina "School_Type"

#Peer_Influence: Hubo diferencia significativa entre
#                     grupos. Negative = -1, Medium = 0, Positive = 1

#Physical_Activity: Variable Numerica Discreta. No hay datos atipicos

#Learning_Disabilities: Si hay diferecnia sognificativa entre
#                     grupos. No = 0, Yes = 1

#	Parental_Education_Level:  Hubo diferencia significativa entre
#                     grupos. High School = 0, College = 1, Postgraduate = 2

#Distance_from_Home: Hubo diferencia significativa entre
#                     grupos. Near = 0, Moderate = 1, Far = 2

#Gender: NO hubo diferencia significativa entre grupos
#              entonces se elimina "School_Type"

#Exam_Score: Variable Numerica Discreta. No hay datos atipicos

# %%
import seaborn as sns
import matplotlib.pyplot as plt
matriz_de_correlacion=df.corr()
plt.figure(figsize=(10,10),dpi=100)
sns.heatmap(
    matriz_de_correlacion,#LO QUE VA A GRAFICAR
    annot=True,#SE MUESTRAN LOS VALORES EN LAS CELDAS
    fmt="0.2f",#0.2f SIGNIFICA "DOS DECIMALES"
    cmap="coolwarm",#PALETA DE COLORES
    square=True,#FORZA CUADRADOS
    linewidths=0.5,#GROSOR DE LINEAS
    cbar_kws={"shrink":0.8},#TAMAÑO BARRA LATERAL
    center=0
)
plt.title("Mapa de calor para matriz de correlacion", fontsize=20),
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5]),
#  [Text(0, 0.5, 'Hours_Studied'),
#   Text(0, 1.5, 'Attendance'),
#   Text(0, 2.5, 'Parental_Involvement'),
#   Text(0, 3.5, 'Access_to_Resources'),
#   Text(0, 4.5, 'Extracurricular_Activities'),
#   Text(0, 5.5, 'Sleep_Hours'),
#   Text(0, 6.5, 'Previous_Scores'),
#   Text(0, 7.5, 'Motivation_Level'),
#   Text(0, 8.5, 'Internet_Access'),
#   Text(0, 9.5, 'Tutoring_Sessions'),
#   Text(0, 10.5, 'Family_Income'),
#   Text(0, 11.5, 'Teacher_Quality'),
#   Text(0, 12.5, 'Peer_Influence'),
#   Text(0, 13.5, 'Physical_Activity'),
#   Text(0, 14.5, 'Learning_Disabilities'),
#   Text(0, 15.5, 'Parental_Education_Level'),
#   Text(0, 16.5, 'Distance_from_Home'),
#   Text(0, 17.5, 'Exam_Score')])

# %%
x = df[["Attendance"]]
y = df["Exam_Score"]


# Diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize = (5, 5), dpi = 100)
plt.scatter(x, y, label = "tension_arteria", color = 'green')
plt.xlabel("Attendance") # nombrar eje x
plt.ylabel("Exam_Score") # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)
plt.legend()#APARECE LO QUE INDICA EL PUNTO
plt.grid()#APARECEN LOS CUADRITOS EN LA TABLA


# Recta de regresión ajustada
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)
plt.figure()
plt.plot(y, y, color = 'black', linestyle = '--')



# Coeficiente de determinación
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')



# Intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')


# Nuevo gráfico de dispersión
residuales = modelo.resid
plt.scatter(y, yc, color = 'purple')
plt.xlabel("Attendance")
plt.ylabel("Exam_Score")
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.grid()#APARECEN LOS CUADRITOS EN LA TABLA


# Prueba de Shapiro para los residuales
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')



# Prueba de Brausch-Pagan para los residuales
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')


# Tabla ANOVA
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols("Exam_Score ~ Attendance", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# Coeficiente de determinación:  0.3367
#
# Intervalo de confianza para b1 de  95%
#  0.1899 < b1 <  0.2034
#
# valor-p de Shapiro:  0.0000
#
# valor_p de Breusch-Pagan:  0.8205
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6378.
#   res = hypotest_fun_out(*samples, **kwds)
#                 df        sum_sq       mean_sq           F  PR(>F)
# Attendance     1.0  32896.461629  32896.461629  3236.54296     0.0
# Residual    6376.0  64806.134796     10.164074         NaN     NaN

# %% [markdown]
# ![Imagen de WhatsApp 2025-07-23 a las 12.41.00_39a2a19a.jpg](data:image/jpeg;base64,...)

# %%
x = df[["Attendance","Hours_Studied","Access_to_Resources", "Previous_Scores"]]
y = df["Exam_Score"]


# Recta de regresión ajustada
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)
plt.figure()
plt.plot(y, y, color = 'black', linestyle = '--')



# Coeficiente de determinación
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')



# Intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')


# Nuevo gráfico de dispersión
residuales = modelo.resid
plt.scatter(y, yc, color = 'purple')
plt.xlabel("Attendance")
plt.ylabel("Exam_Score")
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.grid()#APARECEN LOS CUADRITOS EN LA TABLA


# Prueba de Shapiro para los residuales
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')



# Prueba de Brausch-Pagan para los residuales
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')


# Tabla ANOVA
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols("Exam_Score ~ Attendance + Hours_Studied + Access_to_Resources + Previous_Scores", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# Coeficiente de determinación:  0.5978
#
# Intervalo de confianza para b1 de  95%
#  0.1939 < b1 <  0.2044
#
# valor-p de Shapiro:  0.0000
#
# valor_p de Breusch-Pagan:  0.5625
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6378.
#   res = hypotest_fun_out(*samples, **kwds)
#                          df        sum_sq       mean_sq            F  \
# Attendance              1.0  32896.461629  32896.461629  5334.525641
# Hours_Studied           1.0  19610.099125  19610.099125  3179.994790
# Access_to_Resources     1.0   3051.906635   3051.906635   494.900466
# Previous_Scores         1.0   2843.699328   2843.699328   461.137345
# Residual             6373.0  39300.429707      6.166708          NaN
#
#                             PR(>F)
# Attendance            0.000000e+00
# Hours_Studied         0.000000e+00
# Access_to_Resources  1.181070e-105
# ...

# %% [markdown]
# ![Imagen de WhatsApp 2025-07-23 a las 12.41.00_f729e3dd.jpg](data:image/jpeg;base64,...)
